# %%
import rasterio

# %%
dir = "Z:/cold_data_storage/users/roelfsemam/surdrive_UU/NSA/Downscaling_share/data/processed/2UP_GHSL_2024_M3_Murakami_version_2021_1_CEDS_CMIP7_2025_04_18/IMAGE_ELV-SSP2-CP-D01"
file = "Emissions_CO2_Excl_shipping_aviation_AFOLU_harmonised_IMAGE_ELV-SSP2-CP-D01_2030.tif"
file_path = f"{dir}/{file}"
with rasterio.open(file_path) as src:
    print("CRS:", src.crs)
    print("Transform:", src.transform)
    print("Bounds:", src.bounds)
# Out:
# CRS: EPSG:4326
# Transform: | 0.10, 0.00,-180.00|
# | 0.00,-0.10,-89.90|
# | 0.00, 0.00, 1.00|
# Bounds: BoundingBox(left=-180.0, bottom=-269.9, right=180.0, top=-89.9)
